# %%
# Versão da Linguagem Python Atual
from platform import python_version
print('Versão do Pythin: ', python_version())
# Out:
# Versão do Pythin:  3.9.13

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\chris\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\chris\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chris\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\chris\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\chris\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# pd.__version__

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
netflix['listed_in'].value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %%
netflix['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
netflix.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Remove espaços extras nos valores da coluna "date_added"
# netflix['date_added'] = netflix['date_added'].strip()

# Converte a coluna "date_added" para datetime sem especificar um formato
netflix['date_added'] = pd.to_datetime(netflix['date_added'], errors='coerce')

# Formata a coluna "date_added" para exibir no formato 'dd/mm/aa'
netflix['date_added'] = netflix['date_added'].dt.strftime('%d/%m/%y')

netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0   25/09/21          2020  PG-13     90 min
# 1   24/09/21          2021  TV-MA  2 Seasons
# 2   24/09/21          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0      25/09/21          2020  PG-13     90 min
# 1      24/09/21          2021  TV-MA  2 Seasons
# 2      24/09/21          2021  TV-MA   1 Season
# 3      24/09/21          2021  TV-MA   1 Season
# 4      24/09/21          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802   20/11/19          2007      R    158 min
# 8803   01/07/19          2018  TV-Y7  2 Seasons
# 8804   01/11/19          2009      R     88 min
# 8805   11/01/20          2006     PG     88 min
# 8806   02/03/19          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
netflix['duration'].value_counts()
# Out:
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: duration, Length: 220, dtype: int64

# %%
#Making grouping only in one line, when the recommendation is to do it clear as possible
netflix[['type', 'release_year', 'show_id']].groupby(['release_year', 'type']).count()
# Out:
#                       show_id
# release_year type
# 1925         TV Show        1
# 1942         Movie          2
# 1943         Movie          3
# 1944         Movie          3
# 1945         Movie          3
# ...                       ...
# 2019         TV Show      397
# 2020         Movie        517
#              TV Show      436
# 2021         Movie        277
#              TV Show      315
#
# [119 rows x 1 columns]

# %%
#Making grouping about years and type counts
# Including a filter that's bring only results whose year is upper than 2000
select_series = netflix[['release_year', 'type']]
grouping_data = select_series.groupby(['release_year']).count()
filter_data = grouping_data.query('release_year > 2000')

filter_data
# Out:
#               type
# release_year
# 2001            45
# 2002            51
# 2003            61
# 2004            64
# 2005            80
# 2006            96
# 2007            88
# 2008           136
# 2009           152
# 2010           194
# 2011           185
# 2012           237
# 2013           288
# 2014           352
# 2015           560
# 2016           902
# 2017          1032
# 2018          1147
# 2019          1030
# 2020           953
# 2021           592

# %%
# Conta o número de valores únicos na coluna 'release_year'
unique_count = netflix['release_year'].nunique()
print(unique_count)
# Out:
# 74

# %%
# Renomeando as colunas
netflix = netflix.rename(columns={'release_year': 'year'})
netflix = netflix.rename(columns={'date_added': 'date'})
netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country      date  \
# 0                                                NaN  United States  25/09/21
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa  24/09/21
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN  24/09/21
#
#    year rating   duration                                          listed_in  \
# 0  2020  PG-13     90 min                                      Documentaries
# 1  2021  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  2021  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
# Tenta agrupar por 'year' e 'type' para contar a quantidade de ocorrências
test_groupby = netflix.groupby(['year', 'type']).size()
print(test_groupby)
# Out:
# year  type
# 1925  TV Show      1
# 1942  Movie        2
# 1943  Movie        3
# 1944  Movie        3
# 1945  Movie        3
#                 ...
# 2019  TV Show    397
# 2020  Movie      517
#       TV Show    436
# 2021  Movie      277
#       TV Show    315
# Length: 119, dtype: int64

# %%
import matplotlib.pyplot as plt

# Agrupar por ano e contar a quantidade de filmes
filmes_por_ano = netflix.groupby('year').size().reset_index(name='count')

# Configuração do gráfico
plt.figure(figsize=(10, 6))
plt.plot(filmes_por_ano['year'], filmes_por_ano['count'], marker='o', color='b', linestyle='-', linewidth=2)

# Personalização do gráfico
plt.title('Quantidade de Filmes por Ano')

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exemplo de dados (substitua pelo seu dataframe)
# netflix = pd.DataFrame({'year': [2020, 2021, 2021, 2022, 2022, 2022]})

# Contar o número de filmes por ano
year_counts = netflix['year'].value_counts().sort_index()

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
year_counts.plot(kind='bar', color='skyblue')
plt.title('Número de Filmes por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Filmes')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exemplo de dados (substitua pelo seu dataframe)
# netflix = pd.DataFrame({'type': ['Filme', 'Série', 'Filme', 'Filme', 'Série', 'Documentário']})

# Contar a quantidade de cada tipo de filme
type_counts = netflix['type'].value_counts()

# Criar o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Distribuição por Tipo de Filme')
plt.show()

# %%
netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country      date  \
# 0                                                NaN  United States  25/09/21
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa  24/09/21
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN  24/09/21
#
#    year rating   duration                                          listed_in  \
# 0  2020  PG-13     90 min                                      Documentaries
# 1  2021  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  2021  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
# Dividir as categorias e expandir para contar cada uma individualmente
tags_exploded = netflix['listed_in'].str.split(',').explode().str.strip()

# Contar as 10 tags mais frequentes
top_tags = tags_exploded.value_counts().head(10)

print(top_tags)
# Out:
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: listed_in, dtype: int64
